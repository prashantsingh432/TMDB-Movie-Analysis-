# %%
#importing libraries


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#importing the dataset

df = pd.read_csv('tmdb-movies.csv')
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
#view first 5 rows
df.head(5)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
# basic information about "tmdb-movies" dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %% [markdown]
# ### Handle Duplicates

# %%
#check that any duplicates in dataset>


df.duplicated().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10861    False
# 10862    False
# 10863    False
# 10864    False
# 10865    False
# Length: 10866, dtype: bool>

# %%
#trying different method

df.duplicated().sum()
# Out:
# 1

# %% [markdown]
# there is only 1 duplicated row, we have to drop this row

# %%
#with the help of inplace(permanent change) we will drop that duplicate row


df.drop_duplicates(inplace = True)

# %%
#now for doubble check


df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Now there is no duplicated row in the dataset

# %% [markdown]
# ### Handle Missing Values

# %% [markdown]
# Using Percentage to find missing value on the dataset.

# %%
#finding percentage of null value

df.isnull().sum()/len(df)*100
# Out:
# id                       0.000000
# imdb_id                  0.092039
# popularity               0.000000
# budget                   0.000000
# revenue                  0.000000
# original_title           0.000000
# cast                     0.699494
# homepage                72.977451
# director                 0.404970
# tagline                 25.991717
# keywords                13.741371
# overview                 0.036815
# runtime                  0.000000
# genres                   0.211689
# production_companies     9.479982
# release_date             0.000000
# vote_count               0.000000
# vote_average             0.000000
# release_year             0.000000
# budget_adj               0.000000
# revenue_adj              0.000000
# dtype: float64

# %% [markdown]
# We will drop homepage, director, tagline,imdb_id  and other unnecessary fields that are not helpful in this EDA

# %% [markdown]
# ### Drop Columns

# %%
# Drop columns

df.drop(['imdb_id','homepage','tagline','keywords','overview','production_companies','release_date',
         'vote_count','budget_adj','revenue_adj'], axis=1, inplace=True)

# %%
# For confirmation that columns are dropped

df.head()
# Out:
#        id  popularity     budget     revenue                original_title  \
# 0  135397   32.985763  150000000  1513528810                Jurassic World
# 1   76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  262500   13.112507  110000000   295238201                     Insurgent
# 3  140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#    runtime                                     genres  vote_average  \
# ...

# %% [markdown]
# ### Created Calculated Field

# %%
# Create a column for profit and profit margin

df['profit'] = df["revenue"] - df['budget']
df['profit_margin'] = df['profit']/ df['revenue'] * 100

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10865.000000  10865.000000  1.086500e+04  1.086500e+04  10865.000000
# mean    66066.374413      0.646446  1.462429e+07  3.982690e+07    102.071790
# std     92134.091971      1.000231  3.091428e+07  1.170083e+08     31.382701
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.000000      0.207575  0.000000e+00  0.000000e+00     90.000000
# 50%     20662.000000      0.383831  0.000000e+00  0.000000e+00     99.000000
# 75%     75612.000000      0.713857  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#        vote_average  release_year        profit  profit_margin
# count  10865.000000  10865.000000  1.086500e+04    6164.000000
# mean       5.975012   2001.321859  2.520261e+07           -inf
# std        0.935138     12.813260  9.659103e+07            NaN
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
Q1: Does a higher budget results in higher revenue and profit?

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10865.000000  10865.000000  1.086500e+04  1.086500e+04  10865.000000
# mean    66066.374413      0.646446  1.462429e+07  3.982690e+07    102.071790
# std     92134.091971      1.000231  3.091428e+07  1.170083e+08     31.382701
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.000000      0.207575  0.000000e+00  0.000000e+00     90.000000
# 50%     20662.000000      0.383831  0.000000e+00  0.000000e+00     99.000000
# 75%     75612.000000      0.713857  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#        vote_average  release_year        profit  profit_margin
# count  10865.000000  10865.000000  1.086500e+04    6164.000000
# mean       5.975012   2001.321859  2.520261e+07           -inf
# std        0.935138     12.813260  9.659103e+07            NaN
# ...

# %% [markdown]
# We noticed something interesting here. 50 % of revenue is 0 and in profit column there is a negative profit means loss
#
# loking forward to profit_margin columns , only 6164 rows (56 %) have profit margin means other rows have either $0 in budget or revenue.

# %%
#where buget is more then 0>


budget = df.query('budget > 0')
budget.describe()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\numpy\lib\function_base.py:4527: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#                   id   popularity        budget       revenue      runtime  \
# count    5169.000000  5169.000000  5.169000e+03  5.169000e+03  5169.000000
# mean    45513.725479     0.992400  3.073958e+07  8.029101e+07   107.096150
# std     72730.345078     1.329262  3.890441e+07  1.594865e+08    22.810038
# min         5.000000     0.001117  1.000000e+00  0.000000e+00     0.000000
# 25%      8840.000000     0.347958  6.000000e+06  0.000000e+00    93.000000
# 50%     13008.000000     0.624024  1.700000e+07  2.100156e+07   103.000000
# 75%     44943.000000     1.152417  4.000000e+07  8.945676e+07   117.000000
# max    417859.000000    32.985763  4.250000e+08  2.781506e+09   540.000000
#
#        vote_average  release_year        profit  profit_margin
# count   5169.000000   5169.000000  5.169000e+03    5169.000000
# ...

# %% [markdown]
# this is much better to analyse revenue, profit

# %%
#Buget 

ar = np.arange(1.000000e+00,5.000000e+08,5.000000e+07)

budget['budget'].hist(bins = ar)
plt.title('BAR CHART OF TMDB MOVIE BUDGET')
plt.xlabel('BUDGET OF 100 MILLION')
plt.ylabel('NUMBER OF TBDM MOVIES')
plt.show()

# %%
# Revenue

ar = np.arange(0.000000e+00,3.000000e+09,5.000000e+08)
budget['revenue'].hist(bins= ar)
plt.title("BAR CHART OF TMDB REVENUE")
plt.xlabel("REVENUE (BILLION)")
plt.ylabel("NUMBER OF TMDB MOVIES")
plt.show()

# %%
# Draw the line char for the change of the revenue
revenues = df.groupby('release_year')['revenue'].mean()

plt.plot(revenues)
plt.title('The revenue change from year to year')
plt.xlabel('Year')
plt.ylabel('Revenue')

plt.show()

# %% [markdown]
# From the line chart above, the revenue changed drastically over the year, especially during the period of 1960s. However, the revenue shows an increasing trend from the overall perspective. Next, we need to compare the revenue in different years. Since there are too many years, we aggregate them into decades.

# %%
#years intp decades>

bin_edge = [1960, 1970, 1980, 1990, 2000, 2010, 2015]
bin_names = ['1960s', '1970s', '1980s', '1990s', '2000s', '2010s']
df['decade'] = pd.cut(df['release_year'], bin_edge, labels = bin_names)
df.head()
# Out:
#        id  popularity     budget     revenue                original_title  \
# 0  135397   32.985763  150000000  1513528810                Jurassic World
# 1   76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  262500   13.112507  110000000   295238201                     Insurgent
# 3  140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#    runtime                                     genres  vote_average  \
# ...

# %%
#draw the bar chart to compare the revenue in different decades

rev = df.groupby('decade').revenue.mean()

plt.bar(rev.index, rev.values)
plt.title('comparison of revenue among decades')
plt.xlabel('Decade')
plt.ylabel('Revenue')

plt.show()

# %% [markdown]
# From the bar char above, the revenue increased over the year. The 2010s accounts for the most, while the 1960s accounts for the least.
#
# Next, we need to find the pattern of the high revenue. To order to discover the pattern of the group of high revenues, it is defined that the high revenue is the revenue above the 75% percentile.

# %% [markdown]
# and we can also do this >>

# %%
# Budget vs Revenue

budget.plot(y = 'revenue',x='budget', kind = 'scatter')

plt.title("Scatter Plot of Budget vs Revenue for TMDB Budget")
plt.xlabel("Budget (100 million)")
plt.ylabel("Revenue (100 million)")
plt.show()

# %% [markdown]
# From these chart we analyze that in general, movies with higher budget result in a higher revenue

# %%
# Budget vs Profit
budget.plot(y = 'profit', x = 'budget', kind = 'scatter')

plt.title("Scatter Plot of Budget vs Revenue for TMDB Budget")
plt.xlabel("Budget (100 million)")
plt.xlabel("Profit (100 million)")

plt.show()

# %% [markdown]
# With the help of scatter plot , in general, movies with a higher budget result in a higher profit

# %%
#We will filter for budgets with USD 100 million and more

blockbuster = budget.query('budget > 1.000000e+08')
blockbuster.describe()
# Out:
#                   id  popularity        budget       revenue     runtime  \
# count     282.000000  282.000000  2.820000e+02  2.820000e+02  282.000000
# mean    46172.187943    3.300546  1.544628e+08  4.778548e+08  123.031915
# std     62780.785336    3.535419  4.436161e+07  3.509745e+08   33.718360
# min        22.000000    0.157586  1.020000e+08  0.000000e+00   76.000000
# 25%      2030.000000    1.507585  1.250000e+08  2.453954e+08  102.000000
# 50%     14515.000000    2.437016  1.500000e+08  3.786594e+08  121.000000
# 75%     68723.250000    3.964661  1.750000e+08  6.303428e+08  137.000000
# max    417859.000000   32.985763  4.250000e+08  2.781506e+09  540.000000
#
#        vote_average  release_year        profit  profit_margin
# count    282.000000    282.000000  2.820000e+02     282.000000
# mean       6.345035   2008.485816  3.233920e+08           -inf
# std        0.736825      4.961935  3.362143e+08            NaN
# ...

# %%
blockbuster.shape
# Out:
# (282, 13)

# %%
#for blockbuster movies>> budgest vs profit

blockbuster.plot(y = 'profit', x = 'budget', kind = 'scatter')


plt.title("Scatter Plot of Budget vs. Profit for TMDB Movie ")
plt.xlabel("Budget (hundred million)")
plt.ylabel("Profit (billion)")
plt.show()

# %% [markdown]
# We observe  that a lot more outliers are here when it comes to blockbuster movies with higher budget  they were not having high profit

# %% [markdown]
# Lets find out top 10 movies name with respective highest budget>

# %%
# Using groupby Movie Title, Budget and Profit for Top 10 Movies.


blockbuster_grouped = blockbuster.groupby('original_title')[['budget', 'revenue', 'profit']].sum().sort_values('budget', ascending = False).iloc[:10:]
blockbuster_grouped
# Out:
#                                                 budget     revenue      profit
# original_title
# The Warrior's Way                            425000000    11087569  -413912431
# Pirates of the Caribbean: On Stranger Tides  380000000  1021683000   641683000
# Pirates of the Caribbean: At World's End     300000000   961000000   661000000
# Godzilla                                     290000000   908090363   618090363
# Avengers: Age of Ultron                      280000000  1405035767  1125035767
# Superman Returns                             270000000   391081192   121081192
# Tangled                                      260000000   591794936   331794936
# John Carter                                  260000000   284139100    24139100
# Spider-Man 3                                 258000000   890871626   632871626
# The Lone Ranger                              255000000    89289910  -165710090

# %% [markdown]
# Not even a billion dollar budget can stop a movie from making losses. "The Warrior's Way" and "The Lone Ranger" are loss-making with the former making a USD 400 million loss.

# %% [markdown]
# ## Q2: Which Movie genres are associated with high popularity?

# %% [markdown]
# Before we dive into the analysis, we must first understand what it means by popularity and how is it calculated?

# %% [markdown]
# On TMDB website, the popularity metric is calculated based on Movies, TV Shows and People where it measures the number of votes and views, and number of users who marked it as their "favourite" or added into their "watchlist".
# Source: https://developers.themoviedb.org/3/getting-started/popularity

# %%
df['popularity'].describe()
# Out:
# count    10865.000000
# mean         0.646446
# std          1.000231
# min          0.000065
# 25%          0.207575
# 50%          0.383831
# 75%          0.713857
# max         32.985763
# Name: popularity, dtype: float64

# %% [markdown]
# It is interesting to note that 75% of the data's popularity is 0.71 score and we have the other extreme, a score of 32.98 and not a rating of 10 as we would have expected from a generic popularity scheme.
#
# Why is that so?
#
# I did some research and found an answer on the TMDB forum where one of the staff, Travis Bell shed some light on the popularity calculation.

# %% [markdown]
# Upper (referring to the maximum value of the popularity metric) no, this is the same as before. Lower, 0. It can be anywhere from 0 to essentially infinity.

# %% [markdown]
# What he means is that the popularity score starts from 0 and runs to infinity.
#
# Hmm, that can be tough to measure. Let's get the average popularity and use it as our benchmark.

# %%
df['popularity'].mean()
# Out:
# 0.6464455549010584

# %% [markdown]
# Since the popularity genres for each movies are in a single cell and separated by "|", then we will conduct the splitting first.

# %%
df['genres'] = df['genres'].str.split('|')
df.head(5)
# Out:
#        id  popularity     budget     revenue                original_title  \
# 0  135397   32.985763  150000000  1513528810                Jurassic World
# 1   76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  262500   13.112507  110000000   295238201                     Insurgent
# 3  140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#    runtime                                          genres  vote_average  \
# ...

# %%
genre = df.explode('genres')
genre.head(5)
# Out:
#        id  popularity     budget     revenue      original_title  \
# 0  135397   32.985763  150000000  1513528810      Jurassic World
# 0  135397   32.985763  150000000  1513528810      Jurassic World
# 0  135397   32.985763  150000000  1513528810      Jurassic World
# 0  135397   32.985763  150000000  1513528810      Jurassic World
# 1   76341   28.419936  150000000   378436354  Mad Max: Fury Road
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...    George Miller
#
#    runtime           genres  vote_average  release_year      profit  \
# 0      124           Action           6.5          2015  1363528810
# ...

# %%
genre['genres'].value_counts()
# Out:
# Drama              4760
# Comedy             3793
# Thriller           2907
# Action             2384
# Romance            1712
# Horror             1637
# Adventure          1471
# Crime              1354
# Family             1231
# Science Fiction    1229
# Fantasy             916
# Mystery             810
# Animation           699
# Documentary         520
# Music               408
# History             334
# War                 270
# Foreign             188
# TV Movie            167
# Western             165
# Name: genres, dtype: int64

# %%
plt.figure(figsize = [8,6])
genre['genres'].value_counts().plot.barh()

plt.title('Bar Chart for TMBD Movies')
plt.ylabel("Genres")
plt.xlabel("Count");

# %% [markdown]
# With the help of bar chart > highest count of genres are Drama, comedy and thriller,
# so does it means that they are most popular?

# %%
genre_mean = genre.groupby('genres')[['popularity', 'revenue', 'profit']].mean().sort_values('popularity', ascending = False)
genre_mean.iloc[:10,:].query('popularity > 0.6464455549010583')
# Out:
#                  popularity       revenue        profit
# genres
# Adventure          1.154259  1.131379e+08  7.559417e+07
# Science Fiction    1.001548  7.014056e+07  4.516788e+07
# Fantasy            0.992840  9.631366e+07  6.370107e+07
# Action             0.926274  7.279473e+07  4.506691e+07
# Animation          0.852182  7.525606e+07  5.209628e+07
# Family             0.786668  7.243318e+07  4.907384e+07
# Crime              0.744930  4.236866e+07  2.470486e+07
# Thriller           0.741563  4.172842e+07  2.452072e+07
# War                0.727683  4.760518e+07  2.671330e+07
# Mystery            0.690012  4.021757e+07  2.409830e+07

# %% [markdown]
# it doesnt seems like , here we can see totally different set of popular genres.

# %% [markdown]
# #### Adventure, Science Fiction and Fantasy are the most popular genres

# %% [markdown]
# ## Q3: Which director produces the highest revenue movies?

# %%
df['director'].value_counts()
# Out:
# Woody Allen                 45
# Clint Eastwood              34
# Martin Scorsese             29
# Steven Spielberg            29
# Ridley Scott                23
#                             ..
# Jeffrey Porter               1
# Larry Shaw                   1
# Bill Pohlad                  1
# Andy Hamilton|Guy Jenkin     1
# Harold P. Warren             1
# Name: director, Length: 5067, dtype: int64

# %%
df['director'] = df['director'].str.split("|")
df.head(5)
# Out:
#        id  popularity     budget     revenue                original_title  \
# 0  135397   32.985763  150000000  1513528810                Jurassic World
# 1   76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  262500   13.112507  110000000   295238201                     Insurgent
# 3  140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast            director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   [Colin Trevorrow]
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     [George Miller]
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  [Robert Schwentke]
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       [J.J. Abrams]
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         [James Wan]
#
#    runtime                                          genres  vote_average  \
# ...

# %%
directors_df = df.explode('director')
directors_df.head(5)
# Out:
#        id  popularity     budget     revenue                original_title  \
# 0  135397   32.985763  150000000  1513528810                Jurassic World
# 1   76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  262500   13.112507  110000000   295238201                     Insurgent
# 3  140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#    runtime                                          genres  vote_average  \
# ...

# %%
directors_df['director'].value_counts()
# Out:
# Woody Allen          46
# Clint Eastwood       34
# Martin Scorsese      31
# Steven Spielberg     30
# Steven Soderbergh    23
#                      ..
# Mike Maguire          1
# Tom Kuntz             1
# John Simpson          1
# Simon Hunter          1
# Harold P. Warren      1
# Name: director, Length: 5362, dtype: int64

# %%
directors_df.groupby('director')[['revenue', 'profit']].mean().sort_values('revenue', ascending = False).head(5)
# Out:
#                        revenue        profit
# director
# Pierre Coffin     8.903356e+08  8.173356e+08
# David Yates       8.308591e+08  6.758591e+08
# Colin Trevorrow   7.587683e+08  6.833933e+08
# Robert Stromberg  7.584104e+08  5.784104e+08
# Lee Unkrich       7.439073e+08  6.191573e+08

# %%
directors_df.groupby('director')[['revenue', 'profit']].mean().sort_values('profit', ascending = False).head(5)
# Out:
#                        revenue        profit
# director
# Pierre Coffin     8.903356e+08  8.173356e+08
# Colin Trevorrow   7.587683e+08  6.833933e+08
# David Yates       8.308591e+08  6.758591e+08
# Lee Unkrich       7.439073e+08  6.191573e+08
# Robert Stromberg  7.584104e+08  5.784104e+08

# %% [markdown]
# ## on average , the director who is producing the movie with the highest revenue and profit is Pierre Coffin

# %%
directors_df.query('director == "Pierre Coffin"').sort_values('profit', ascending =False).head(3)
# Out:
#           id  popularity    budget     revenue   original_title  \
# 8     211672    7.404165  74000000  1156730962          Minions
# 5434   93456    3.928789  76000000   970761885  Despicable Me 2
# 1924   20352    3.791881  69000000   543513985    Despicable Me
#
#                                                    cast       director  \
# 8     Sandra Bullock|Jon Hamm|Michael Keaton|Allison...  Pierre Coffin
# 5434  Steve Carell|Kristen Wiig|Benjamin Bratt|Miran...  Pierre Coffin
# 1924  Steve Carell|Jason Segel|Russell Brand|Julie A...  Pierre Coffin
#
#       runtime                                  genres  vote_average  \
# 8          91  [Family, Animation, Adventure, Comedy]           6.5
# 5434       98             [Animation, Comedy, Family]           7.0
# 1924       95             [Action, Animation, Family]           7.1
#
#       release_year      profit  profit_margin
# 8             2015  1082730962      93.602661
# 5434          2013   894761885      92.171098
# ...

# %% [markdown]
# Despicable Me, minions movies series is well loved by both kids and adults

# %% [markdown]
# ## Q4: Which actor is associated with higher popularity, revenue and profit?

# %%
df['cast'].value_counts()
# Out:
# Louis C.K.                                                                        6
# William Shatner|Leonard Nimoy|DeForest Kelley|James Doohan|George Takei           5
# Bill Burr                                                                         4
# George Carlin                                                                     3
# Pierre Coffin                                                                     3
#                                                                                  ..
# Ray Stevenson|Vincent D'Onofrio|Val Kilmer|Christopher Walken|Linda Cardellini    1
# Freida Pinto|Riz Ahmed|Roshan Seth|Kalki Koechlin|Anurag Kashyap                  1
# William Hurt|Paul Giamatti|James Woods|Billy Crudup|Topher Grace                  1
# Dennis Quaid|Tony Oller|Aimee Teegarden|Stephen Lunsford|Devon Werkheiser         1
# Harold P. Warren|Tom Neyman|John Reynolds|Diane Mahree|Stephanie Nielson          1
# Name: cast, Length: 10719, dtype: int64

# %%
df['cast'].describe()
# Out:
# count          10789
# unique         10719
# top       Louis C.K.
# freq               6
# Name: cast, dtype: object

# %%
df['cast'] = df['cast'].astype(str)
df.head(1)
# Out:
#        id  popularity     budget     revenue  original_title  \
# 0  135397   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
#
#    runtime                                     genres  vote_average  \
# 0      124  Action|Adventure|Science Fiction|Thriller           6.5
#
#    release_year      profit  profit_margin
# 0          2015  1363528810      90.089386

# %%
cast_df = df.explode('cast')
cast_df.head(1)
# Out:
#        id  popularity     budget     revenue  original_title  \
# 0  135397   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
#
#    runtime                                     genres  vote_average  \
# 0      124  Action|Adventure|Science Fiction|Thriller           6.5
#
#    release_year      profit  profit_margin
# 0          2015  1363528810      90.089386

# %%
cast_df['cast'].value_counts()
# Out:
# nan                                                                               76
# Louis C.K.                                                                         6
# William Shatner|Leonard Nimoy|DeForest Kelley|James Doohan|George Takei            5
# Bill Burr                                                                          4
# George Carlin                                                                      3
#                                                                                   ..
# Ray Stevenson|Vincent D'Onofrio|Val Kilmer|Christopher Walken|Linda Cardellini     1
# Freida Pinto|Riz Ahmed|Roshan Seth|Kalki Koechlin|Anurag Kashyap                   1
# William Hurt|Paul Giamatti|James Woods|Billy Crudup|Topher Grace                   1
# Dennis Quaid|Tony Oller|Aimee Teegarden|Stephen Lunsford|Devon Werkheiser          1
# Harold P. Warren|Tom Neyman|John Reynolds|Diane Mahree|Stephanie Nielson           1
# Name: cast, Length: 10720, dtype: int64

# %%
cast_df.groupby('cast')[['popularity','revenue']].sum().sort_values('revenue',ascending=False)
# Out:
#                                                     popularity     revenue
# cast
# Elijah Wood|Ian McKellen|Viggo Mortensen|Liv Ty...   23.793149  2916544743
# Sam Worthington|Zoe Saldana|Sigourney Weaver|St...    9.432768  2781505847
# Jennifer Lawrence|Josh Hutcherson|Liam Hemswort...   12.969332  2189157571
# Harrison Ford|Mark Hamill|Carrie Fisher|Adam Dr...   11.173104  2068178225
# Martin Freeman|Ian McKellen|Richard Armitage|Ke...   14.485385  1913519788
# ...                                                        ...         ...
# Jennifer Love Hewitt|Colin Ferguson|Natassia Ma...    0.229908           0
# Jennifer Love Hewitt|Betty White|Sean Faris|Gil...    0.144722           0
# Jennifer Lopez|Martin Sheen|Antonio Banderas|Ma...    1.099328           0
# Jennifer Lawrence|Selma Blair|Bokeem Woodbine|C...    0.358438           0
# Ã€lex BrendemÃ¼hl|TÃ³mas Lemarquis|Derek de Lin...    0.153962           0
#
# [10720 rows x 2 columns]

# %%
values('revenue',ascending=False).head(5)
po

# %% [markdown]
# Q5: Which year produced movies with highest grossing revenue?Q5: Which year produced movies with highest grossing revenue?

# %%
df.sort_values('revenue',ascending=False).head(1)
# Out:
#          id  popularity     budget     revenue original_title  \
# 1386  19995    9.432768  237000000  2781505847         Avatar
#
#                                                    cast       director  \
# 1386  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#       runtime                                    genres  vote_average  \
# 1386      162  Action|Adventure|Fantasy|Science Fiction           7.1
#
#       release_year      profit  profit_margin
# 1386          2009  2544505847      91.479435

# %% [markdown]
# #### Avatar produced in 2009 has the highest grossing revenue.

# %% [markdown]
# ### Conclusions

# %% [markdown]
# lets summarize our conclusion.

# %% [markdown]
# ### Q1: Does having a higher budget results in a higher revenue and profit?

# %% [markdown]
# #### In most cases, a higher budget does results in higher revenue and profit. However, the analysis shows that there are outlier where a high budget results in losses.

# %% [markdown]
# #### The revenue changed drastically over the year but showed an overall increase. The 1960s accounts for the least, while the 2010s accounts for the most.

# %% [markdown]
# ### Q2: Which genres are associated with high popularity?

# %% [markdown]
# #### Adventure, Science Fiction and Fantasy are the most popular genres.

# %% [markdown]
# ### Q3: Which director produces the highest revenue movies?

# %% [markdown]
# Pierre Coffin is the director who produced the highest revenue movie with the Despicable Me movies.

# %% [markdown]
# ### Q4: Which actor is associated with higher popularity, revenue and profit?

# %% [markdown]
# Actors associated with higher revenue and profit are Harrison Ford, Tom Hanks and Tom Cruise.

# %% [markdown]
# ### Q5: Which year produced movies with highest grossing revenue?

# %% [markdown]
# Avatar produced in 2009 has the highest grossing revenue at USD 2.7 billion.

# %% [markdown]
# In conclusion, the factors contributing to a Box Office success is not only having a billion dollar budget, the right genre, director, and star-studded casts also contributed to the revenue.

# %% [markdown]
# ### Limitations of Dataset
# 1. 43% of dataset have USD 0 budget, hence the profit analysis is representative of the remaining 57% of dataset only.
#
# 2. The revenue and budget were not denominated in currency, so it’s unsure whether they are in USD, or another currency.
#
# 3. There were multiple genres in each movie, hence we split the genres such that each genre is allocated to 1 row.

# %% [markdown]
# ### Reference
# https://pandas.pydata.org/docs/user_guide/index.html
# https://www.investopedia.com/financial-edge/0611/why-movies-cost-so-much-to-make.aspx
# https://developers.themoviedb.org/3/getting-started/popularity
